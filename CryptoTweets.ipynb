# %% [markdown]
# <a href="https://colab.research.google.com/github/rodincode/CryptoTweets/blob/main/CryptoTweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/Dogecoin%20Historical%20Data%20-%20Investing.com%20India.csv",index_col="Date",parse_dates=['Date'])
df = df.drop(columns=["Vol."])
df.head()
# Out:
#                Price      Open      High       Low Change %
# Date
# 2021-06-13  0.306881  0.309628  0.312770  0.305272   -0.88%
# 2021-06-12  0.309604  0.316841  0.316841  0.299227   -2.28%
# 2021-06-11  0.316842  0.325036  0.331803  0.310883   -2.48%
# 2021-06-10  0.324914  0.342524  0.344416  0.321813   -5.15%
# 2021-06-09  0.342546  0.326036  0.352889  0.312234    5.07%

# %%
ax = df.plot(figsize=(15,7))
ax

# %%
dft1 = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/ElonMuskTweets2020.csv")
dft1 = pd.concat([dft1["date"],dft1["tweet"]],axis = 1)
dft1.head()
# Out:
#                   date                                              tweet
# 0  2020-12-28 19:46:18  Entertainment will be critical when cars drive...
# 1  2020-12-28 18:07:33  @kimpaquette Just meeting with Larry Ellison t...
# 2  2020-12-28 17:23:51                        @richierichhhhh_ Absolutely
# 3  2020-12-28 17:23:31  What should Tesla do with in-car gaming in an ...
# 4  2020-12-28 05:39:42                          @PPathole @WSJ Absolutely

# %%
dft2 = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/ElonMuskTweets2021.csv")
dft2 = pd.concat([dft2["date"],dft2["tweet"]],axis = 1)
dft2.head()  #2010-06-04 till 2021-03-22
# Out:
#                   date                                              tweet
# 0  2021-03-22 02:10:37  @bluemoondance74 @NASASpaceflight Going well. ...
# 1  2021-03-21 20:39:07  @NASASpaceflight Hopefully will happen this de...
# 2  2021-03-21 08:42:00                                 @newscientist True
# 3  2021-03-21 05:31:31  @cleantechnica I am accumulating resources to ...
# 4  2021-03-21 04:32:11  @CathieDWood When vast amounts of manufacturin...

# %%
dogedf = dft2[dft2['tweet'].str.contains("Dogecoin|dogecoin|DOGECOIN|DogeCoin")]
dogedf
# Out:
#                      date                                              tweet
# 58    2021-03-13 23:46:16  Origin of Doge Day Afternoon: The ancient Roma...
# 149   2021-03-02 08:36:34                 @draecomino 2022: Dogecoin is dumb
# 221   2021-02-20 10:06:29  @PPathole @dogecoin Just some used Antminer L3...
# 223   2021-02-20 08:42:28  @dogecoin I just set up some little Doge minin...
# 254   2021-02-14 23:25:16  If major Dogecoin holders sell most of their c...
# 276   2021-02-10 15:08:11  Bought some Dogecoin for lil X, so he can be a...
# 310   2021-02-07 02:36:32                      @Jbuttermost @Dogecoinrich 🤣🤣
# 312   2021-02-07 02:24:19                                   @Dogecoinrich 🤣🤣
# 351   2021-02-04 08:15:26                    Dogecoin is the people’s crypto
# 2977  2020-04-25 13:29:52       @28delayslater @justpaulinelol Dogecoin Mode
# 6219  2019-04-02 20:38:38   Dogecoin value may vary  https://t.co/UWerAhPv63
# ...

# %%
doge = dogedf["date"]
dogedates=[]
for i in doge:
  date = i.split()[0]
  print(date)
  dogedates.append(date)
# Out:
# 2021-03-13
# 2021-03-02
# 2021-02-20
# 2021-02-20
# 2021-02-14
# 2021-02-10
# 2021-02-07
# 2021-02-07
# 2021-02-04
# 2020-04-25
# 2019-04-02
# 2019-04-02
# 2019-04-02
# 2019-04-02

# %%
cryptweets = df[df.index.isin(dogedates)]
cryptweets
# Out:
#                Price      Open      High       Low Change %
# Date
# 2021-03-13  0.062694  0.055238  0.062739  0.054694   13.45%
# 2021-03-02  0.050279  0.050582  0.052423  0.049198   -0.59%
# 2021-02-20  0.054135  0.055044  0.060455  0.051115   -1.64%
# 2021-02-14  0.062639  0.066244  0.066392  0.055785   -5.45%
# 2021-02-10  0.072584  0.070015  0.081396  0.067081    3.67%
# 2021-02-07  0.078508  0.057506  0.086356  0.053464   36.62%
# 2021-02-04  0.052944  0.037340  0.059081  0.035919   41.77%

# %%
cryptweets.plot(style=['+-','o-','.--','s:',".-"],figsize=(15,7))

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.style.use("fivethirtyeight")

fig, ax = plt.subplots(figsize=(15,7))

ax.plot(df.index, df["Open"],linewidth = 2, alpha = .7, label='Open')
ax.legend(loc="upper left") 
ax.plot(df.index, df["High"],linewidth = 2, alpha = .7, label='High') 
ax.legend(loc="upper left")       
ax.plot(df.index, df["Low"],linewidth = 2, alpha = .7, label='Low')
ax.legend(loc="upper left")        
# ax.plot(df.index, df["Close"],linewidth = 2, alpha = .7, label='Close')
# ax.legend(loc="upper left") 
# ax.plot(df.index, df["Adj Close"],linewidth = 2, alpha = .7, label='Adj Close')   
# ax.legend(loc="upper left")     

ax.plot(cryptweets.index, cryptweets["Open"],"bo", label="Musk's Tweets")
ax.legend(loc="upper left") 
ax.set(xlabel="Date",
       title="DOGECOIN on Elon Musk's Tweet")
# Format the x axis
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=10))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%m-%d-%y"))


ax.annotate('Elon Musk Tweeted',xy=(mdates.date2num(cryptweets.index[0]),2.712202),xytext=(-150, 90), 
            textcoords='offset points', arrowprops=dict(arrowstyle='fancy',facecolor="black"))
ax.xaxis.zoom(0.5)
plt.show()
