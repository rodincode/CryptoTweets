# %% [markdown]
# <a href="https://colab.research.google.com/github/rodincode/CryptoTweets/blob/main/CryptoTweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part - 1 : Collecting Data

# %% [markdown]
# # Reading Data

# %%
import pandas as pd
doge_df = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/Dogecoin%20Historical%20Data%20-%20Investing.com%20India.csv",index_col="Date",parse_dates=['Date'])
doge_df = doge_df.drop(columns=["Vol.","Change %"])
bit_df = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/Bitcoin%20Historical%20Data%20-%20Investing.com%20India.csv",index_col = "Date",parse_dates = ["Date"])
bit_df = bit_df.drop(columns=["Vol.","Change %"])
# if you want to operate on multiple columns, put them in a list like so:
bit_df.replace(',','', regex=True, inplace=True)
bit_df = bit_df.astype(float)
print(doge_df.head())
print(bit_df.head())
# Out:
#                Price      Open      High       Low
# Date
# 2021-06-13  0.306881  0.309628  0.312770  0.305272
# 2021-06-12  0.309604  0.316841  0.316841  0.299227
# 2021-06-11  0.316842  0.325036  0.331803  0.310883
# 2021-06-10  0.324914  0.342524  0.344416  0.321813
# 2021-06-09  0.342546  0.326036  0.352889  0.312234
#               Price     Open     High      Low
# Date
# 2021-06-13  34931.4  35467.5  35903.9  34827.0
# 2021-06-12  35467.5  37334.4  37437.3  34703.3
# 2021-06-11  37314.6  36654.3  37641.1  36003.3
# 2021-06-10  36649.4  37375.2  38340.8  35824.0
# 2021-06-09  37332.2  33385.5  37517.6  32428.6

# %% [markdown]
# #Dogecoin Plot

# %%
axd = doge_df.plot(figsize=(15,7),title = "Dogecoin from 01/06/20 to 13/06/21")
axd

# %% [markdown]
# # BitCoin Plot

# %%
axb = bit_df.plot(figsize=(15,7),title = "Bitcoin from 01/06/20 to 13/06/21")
axb

# %% [markdown]
# # Tokens

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#Load the Twitter packages
import tweepy
api_key = "QU8L989sUVlxec1PWfonD54QX"
api_secret_key = "h5vjwA6jqCQnARn1W3HrrpPBRiCO873j84IMKvGjDxGqYt5rQY"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAMZ%2FQgEAAAAAtT9CpEX8%2FNU7jE971xqHGaNrIsE%3DFYstlFu7GByL45JlPZcQfRqvVfAo6DeKBLdIw9FrPzvvlMuOWuNPl...TvpX2DSn5HtZKEn67tJI..."
access_token = "1103347220617687041-zi3nI04BUzwgXJ0etkInF3jR7kkJhW"
access_token_secret = "LGNgC51MYieLebk2xisM1Rjy5FSC70iaYu7xUmAH5V1Pc"

# Create The Authenticate Object
authenticate = tweepy.OAuthHandler(api_key, api_secret_key)

# Set The Access Token & Access Token Secret
authenticate.set_access_token(access_token, access_token_secret)

# Create The API Object
api = tweepy.API(authenticate, wait_on_rate_limit = True)

# %% [markdown]
# # Musk's Tweets

# %%
try:
  screen_name = 'elonmusk'
  count = 200
  # Creation of query method using parameters

  new_tweets = api.user_timeline(screen_name = screen_name,count = 200)

  alltweets = []
  alltweets.extend(new_tweets) 
  oldest_tweet = alltweets[-1].id - 1
  while len(new_tweets)>0:
    new_tweets = api.user_timeline(screen_name = screen_name,count = 200)
    alltweets.extend(new_tweets)
    oldest_tweet = alltweets[-1].id - 1


  print("Pulling all",len(alltweets),"tweets")
  #print(alltweets)
  # # Pulling information from tweets iterable object
  tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in alltweets if "dogecoin" in tweet.text.lower()]

  # # Creation of dataframe from tweets list
  # # Add or remove columns as you remove tweet information
  tweets_df = pd.DataFrame(tweets_list)
  tweets_df.columns = ["Date","Id","Tweet"]
  tweets_df.to_csv("ElonTweets(on Dogecoin).csv")
  tweets_df
except:
  print("Failed to fetch data. Run once again ;)")
# Out:
# Pulling all 240 tweets

# %% [markdown]
# #Jack's Tweets

# %%
username = 'jack'
count = 200
   
# Creation of query method using parameters
tweets = tweepy.Cursor(api.user_timeline,id=username).items(count)

# Pulling information from tweets iterable object
tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets if "bitcoin" in tweet.text.lower()]

# Creation of dataframe from tweets list
# Add or remove columns as you remove tweet information
tweets_df = pd.DataFrame(tweets_list)
tweets_df.columns = ["Date","Id","Tweet"]
tweets_df.to_csv("JackTweets(on Bitcoin).csv")
tweets_df
# Out:
#                   Date  ...                                              Tweet
# 0  2021-06-13 20:18:39  ...  RT @DocumentingBTC: Venezuela 🇻🇪 has the 3rd h...
# 1  2021-06-13 01:52:33  ...                  🌍#Bitcoin https://t.co/5RgLqdfk7k
# 2  2021-06-13 01:34:22  ...  RT @michael_saylor: On Wednesday, you are all ...
# 3  2021-06-13 01:31:18  ...  The people of Nigeria will lead #bitcoin 🇳🇬 ht...
# 4  2021-06-12 20:33:31  ...                                        🇳🇬🤝#bitcoin
# 5  2021-06-12 13:05:33  ...  RT @builtwithbtc: We're Built With Bitcoin 👋\n...
# 6  2021-06-12 12:44:39  ...  RT @bitentrepreneur: TAPROOT has locked-in. Ex...
# 7  2021-06-11 19:55:35  ...  "…useless complicated math problems…"\n\n@SenW...
# 8  2021-06-11 04:20:31  ...  RT @TechCortes: Seguiremos hablando un solo le...
# 9  2021-06-11 04:08:15  ...      RT @camilacampton: #Bitcoin is for everyone 🧡
# 10 2021-06-11 03:53:00  ...  RT @criptobastardo: Todos hablamos un lenguaje...
# 11 2021-06-11 03:39:46  ...       de nuevo #bitcoin \n https://t.co/NDoRpMSwcj
# 12 2021-06-11 02:52:42  ...  “We all speak one language, and it is #bitcoin...
# 13 2021-06-11 01:58:48  ...  RT @nayibbukele: Soon, that well is going to l...
# 14 2021-06-09 23:45:48  ...  #bitcoin  incentivizes renewable energy https:...
# 15 2021-06-09 18:17:43  ...  RT @DocumentingBTC: El Salvador 🇸🇻 may soon be...
# 16 2021-06-09 17:47:37  ...  RT @milessuter: Lots of bitcoiners are asking ...
# 17 2021-06-09 15:29:05  ...  RT @CaitlinLong_: WHAT I FIND MOST SIGNIFICANT...
# 18 2021-06-09 15:28:14  ...  RT @DocumentingBTC: Wikipedia now lists #Bitco...
# 19 2021-06-05 23:08:55  ...  RT @BTCTN: “Next week, I will send to congress...
# 20 2021-06-05 21:00:40  ...  RT @gladstein: Historic moment.\n\nEl Salvador...
# 21 2021-06-05 18:00:58  ...  RT @Square: We’re committed to driving further...
# 22 2021-06-04 15:37:41  ...  2/“No keys, no cheese.” The exchange you used ...
# 23 2021-06-04 15:37:41  ...  1/Bitcoin is for everyone. It’s important to u...
# 24 2021-06-04 15:37:41  ...  Square is considering making a hardware wallet...
# 25 2021-06-02 16:52:39  ...  RT @moneyball: The full power of bitcoin is on...
# 26 2021-05-27 13:00:38  ...  RT @gladstein: 1/ My latest essay is live:\n\n...
# 27 2021-05-27 00:49:16  ...  RT @tjma2001: Bitcoin is African. This shit wa...
# 28 2021-05-26 04:11:05  ...  RT @DocumentingBTC: Africa is leading the worl...
# 29 2021-05-25 16:20:27  ...  RT @sqcrypto: New grant. Dhruv Mehta (@dhruv) ...
# 30 2021-05-24 16:02:02  ...  RT @sqcrypto: Please welcome Conor Okus (@cono...
# 31 2021-05-21 08:56:03  ...  RT @milessuter: Calling all #Bitcoin Operators...
# 32 2021-05-19 17:15:47  ...  RT @RajarshiMaitra: Officially quit my fiat jo...
# 33 2021-05-14 22:44:07  ...  @l_ToxjQ_l @gladstein @knutsvanholm extremely ...
# 34 2021-05-14 20:59:38  ...  #bitcoin changes *everything*…for the better.\...
# 35 2021-05-09 18:41:50  ...  RT @seyitaylor: Create Afrofuturist Art.\nWin ...
# 36 2021-05-07 13:46:08  ...  RT @NBCNewsTHINK: Bitcoin gets Wall Street's a...
# 37 2021-04-28 13:08:28  ...  RT @CoinDesk: NEW: @CashApp has added former @...
# 38 2021-04-28 13:05:31  ...  RT @NeerajKA: Bitcoin Peer-to-Peer Trading Up ...
# 39 2021-04-27 17:32:59  ...  RT @TheBlueMatt: Literally the thing many bitc...
# 40 2021-04-21 16:16:35  ...  #bitcoin incentivizes renewable energy https:/...
# 41 2021-04-15 15:56:27  ...  RT @TheBlueMatt: Tomorrow is officially @fanqu...
# 42 2021-04-13 17:49:11  ...  RT @replit: Announcing Replit Ventures 🚀 A new...
# 43 2021-04-13 16:32:22  ...  RT @coryklippsten: Bitcoin isn't "rife with il...
# 44 2021-04-07 17:03:23  ...  RT @sqcrypto: Not even 2 weeks after announcin...
# 45 2021-04-06 16:26:05  ...    Announcing CCI #bitcoin https://t.co/cT3AQf0op7
# 46 2021-03-31 19:36:25  ...  RT @MITBitcoinClub: Join us tonight at 8pm ET ...
# 47 2021-03-29 16:24:27  ...  RT @moneyball: Early adopter of #bitcoin as un...
# 48 2021-03-18 16:45:40  ...    beautiful work #bitcoin https://t.co/BErHZ2wUts
# 49 2021-03-17 16:39:18  ...             #bitcoin first https://t.co/vd5fBRSkkn
#
# [50 rows x 3 columns]

# %% [markdown]
# # Part-2 : Plotting and marking tweets

# %% [markdown]
# > Reading the pulled tweets
#
# * Elon Musk's for Dogecoin
#
# * Jack Dorsey's for Bitcoin

# %%
dogeTweets_df = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/ElonTweets(on%20Dogecoin).csv")
bitTweets_df = pd.read_csv("https://raw.githubusercontent.com/rodincode/CryptoTweets/main/JackTweets(on%20Bitcoin).csv")
print(dogeTweets_df, bitTweets_df)
# Out:
#     Unnamed: 0  ...                                              Tweet
# 0            0  ...  @lexfridman @VitalikButerin @ethereum @Bitcoin...
# 1            1  ...         @ItsDogeCoin @RTHowell Haf yu sin mi danz?
# 2            2  ...  @hiddin2urleft @greg16676935420 @blockfolio @B...
# 3            3  ...  @itsALLrisky Please note Dogecoin has no forma...
# 4            4  ...  @heydave7 @dogecoin_devs Doge has dogs &amp; m...
# 5            5  ...  Someone suggested changing Dogecoin fees based...
# 6            6  ...  If you’d like to help develop Doge, please sub...
# 7            7  ...  @lexfridman @VitalikButerin @ethereum @Bitcoin...
# 8            8  ...         @ItsDogeCoin @RTHowell Haf yu sin mi danz?
# 9            9  ...  @hiddin2urleft @greg16676935420 @blockfolio @B...
# 10          10  ...  @itsALLrisky Please note Dogecoin has no forma...
# 11          11  ...  @heydave7 @dogecoin_devs Doge has dogs &amp; m...
# 12          12  ...  Someone suggested changing Dogecoin fees based...
# 13          13  ...  If you’d like to help develop Doge, please sub...
# 14          14  ...  @lexfridman @VitalikButerin @ethereum @Bitcoin...
# 15          15  ...         @ItsDogeCoin @RTHowell Haf yu sin mi danz?
# 16          16  ...  @hiddin2urleft @greg16676935420 @blockfolio @B...
# 17          17  ...  @itsALLrisky Please note Dogecoin has no forma...
# 18          18  ...  @heydave7 @dogecoin_devs Doge has dogs &amp; m...
# 19          19  ...  Someone suggested changing Dogecoin fees based...
# 20          20  ...  If you’d like to help develop Doge, please sub...
# 21          21  ...  @lexfridman @VitalikButerin @ethereum @Bitcoin...
# 22          22  ...         @ItsDogeCoin @RTHowell Haf yu sin mi danz?
# 23          23  ...  @hiddin2urleft @greg16676935420 @blockfolio @B...
# 24          24  ...  @itsALLrisky Please note Dogecoin has no forma...
# 25          25  ...  @heydave7 @dogecoin_devs Doge has dogs &amp; m...
# 26          26  ...  Someone suggested changing Dogecoin fees based...
# 27          27  ...  If you’d like to help develop Doge, please sub...
# 28          28  ...  @lexfridman @VitalikButerin @ethereum @Bitcoin...
# 29          29  ...         @ItsDogeCoin @RTHowell Haf yu sin mi danz?
# 30          30  ...  @hiddin2urleft @greg16676935420 @blockfolio @B...
# 31          31  ...  @itsALLrisky Please note Dogecoin has no forma...
# 32          32  ...  @heydave7 @dogecoin_devs Doge has dogs &amp; m...
# 33          33  ...  Someone suggested changing Dogecoin fees based...
# 34          34  ...  If you’d like to help develop Doge, please sub...
#
# [35 rows x 4 columns]     Unnamed: 0  ...                                              Tweet
# 0            0  ...  RT @DocumentingBTC: Venezuela 🇻🇪 has the 3rd h...
# 1            1  ...                  🌍#Bitcoin https://t.co/5RgLqdfk7k
# 2            2  ...  RT @michael_saylor: On Wednesday, you are all ...
# 3            3  ...  The people of Nigeria will lead #bitcoin 🇳🇬 ht...
# 4            4  ...                                        🇳🇬🤝#bitcoin
# 5            5  ...  RT @builtwithbtc: We're Built With Bitcoin 👋\n...
# 6            6  ...  RT @bitentrepreneur: TAPROOT has locked-in. Ex...
# 7            7  ...  "…useless complicated math problems…"\n\n@SenW...
# 8            8  ...  RT @TechCortes: Seguiremos hablando un solo le...
# 9            9  ...      RT @camilacampton: #Bitcoin is for everyone 🧡
# 10          10  ...  RT @criptobastardo: Todos hablamos un lenguaje...
# 11          11  ...       de nuevo #bitcoin \n https://t.co/NDoRpMSwcj
# 12          12  ...  “We all speak one language, and it is #bitcoin...
# 13          13  ...  RT @nayibbukele: Soon, that well is going to l...
# 14          14  ...  #bitcoin  incentivizes renewable energy https:...
# 15          15  ...  RT @DocumentingBTC: El Salvador 🇸🇻 may soon be...
# 16          16  ...  RT @milessuter: Lots of bitcoiners are asking ...
# 17          17  ...  RT @CaitlinLong_: WHAT I FIND MOST SIGNIFICANT...
# 18          18  ...  RT @DocumentingBTC: Wikipedia now lists #Bitco...
# 19          19  ...  RT @BTCTN: “Next week, I will send to congress...
# 20          20  ...  RT @gladstein: Historic moment.\n\nEl Salvador...
# 21          21  ...  RT @Square: We’re committed to driving further...
# 22          22  ...  2/“No keys, no cheese.” The exchange you used ...
# 23          23  ...  1/Bitcoin is for everyone. It’s important to u...
# 24          24  ...  Square is considering making a hardware wallet...
# 25          25  ...  RT @moneyball: The full power of bitcoin is on...
# 26          26  ...  RT @gladstein: 1/ My latest essay is live:\n\n...
# 27          27  ...  RT @tjma2001: Bitcoin is African. This shit wa...
# 28          28  ...  RT @DocumentingBTC: Africa is leading the worl...
# 29          29  ...  RT @sqcrypto: New grant. Dhruv Mehta (@dhruv) ...
# 30          30  ...  RT @sqcrypto: Please welcome Conor Okus (@cono...
# 31          31  ...  RT @milessuter: Calling all #Bitcoin Operators...
# 32          32  ...  RT @RajarshiMaitra: Officially quit my fiat jo...
# 33          33  ...  @l_ToxjQ_l @gladstein @knutsvanholm extremely ...
# 34          34  ...  #bitcoin changes *everything*…for the better.\...
# 35          35  ...  RT @seyitaylor: Create Afrofuturist Art.\nWin ...
# 36          36  ...  RT @NBCNewsTHINK: Bitcoin gets Wall Street's a...
# 37          37  ...  RT @CoinDesk: NEW: @CashApp has added former @...
# 38          38  ...  RT @NeerajKA: Bitcoin Peer-to-Peer Trading Up ...
# 39          39  ...  RT @TheBlueMatt: Literally the thing many bitc...
# 40          40  ...  #bitcoin incentivizes renewable energy https:/...
# 41          41  ...  RT @TheBlueMatt: Tomorrow is officially @fanqu...
# 42          42  ...  RT @replit: Announcing Replit Ventures 🚀 A new...
# 43          43  ...  RT @coryklippsten: Bitcoin isn't "rife with il...
# 44          44  ...  RT @sqcrypto: Not even 2 weeks after announcin...
# 45          45  ...    Announcing CCI #bitcoin https://t.co/cT3AQf0op7
# 46          46  ...  RT @MITBitcoinClub: Join us tonight at 8pm ET ...
# 47          47  ...  RT @moneyball: Early adopter of #bitcoin as un...
# 48          48  ...    beautiful work #bitcoin https://t.co/BErHZ2wUts
# 49          49  ...             #bitcoin first https://t.co/vd5fBRSkkn
#
# [50 rows x 4 columns]

# %%
dogeDates=[]
# for i in dogeTweets_df["Date"]:
#   date = i.split()[0]  # splitting because we don't want time
#   #print(date)
#   dogeDates.append(date)

### Adding Dates Manually ####
dogeDates.extend(["2021-06-04","2021-05-23","2021-05-20","2021-05-13","2021-05-08","2020-07-18"])

# %%
bitDates=[]
for i in bitTweets_df["Date"]:
  date = i.split()[0]
  #print(date)
  bitDates.append(date)

# %%
dogeTweets = doge_df[doge_df.index.isin(dogeDates)]
dogeTweets.head()
# Out:
#                Price      Open      High       Low
# Date
# 2021-06-04  0.375950  0.399356  0.399609  0.349920
# 2021-05-23  0.305984  0.341509  0.349669  0.249235
# 2021-05-20  0.397741  0.330407  0.432618  0.297074
# 2021-05-13  0.486910  0.389257  0.514831  0.353838
# 2021-05-08  0.634394  0.686914  0.738255  0.605162

# %%
bitTweets = bit_df[bit_df.index.isin(bitDates)]
bitTweets.head()
# Out:
#               Price     Open     High      Low
# Date
# 2021-06-13  34931.4  35467.5  35903.9  34827.0
# 2021-06-12  35467.5  37334.4  37437.3  34703.3
# 2021-06-11  37314.6  36654.3  37641.1  36003.3
# 2021-06-09  37332.2  33385.5  37517.6  32428.6
# 2021-06-05  35520.0  36841.2  37887.6  34832.0

# %%
dogeTweets.plot(style=['+-','o-','.--','s:',".-"],figsize=(15,7),title="DogeCoin when Elon Musk Tweeted")

# %%
bitTweets.plot(style=['+-','o-','.--','s:',".-"],figsize=(15,7),title="DogeCoin when Jack Dorsey Tweeted")

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.image as image

plt.style.use("fivethirtyeight")

fig, ax = plt.subplots(figsize=(15,7))

ax.plot(doge_df.index, doge_df["Open"],linewidth = 2, alpha = .7, label='Open')
ax.legend(loc="upper left") 
ax.plot(doge_df.index, doge_df["High"],linewidth = 2, alpha = .7, label='High') 
ax.legend(loc="upper left")       
ax.plot(doge_df.index, doge_df["Low"],linewidth = 2, alpha = .7, label='Low')
ax.legend(loc="upper left")        
# ax.plot(df.index, df["Close"],linewidth = 2, alpha = .7, label='Close')
# ax.legend(loc="upper left") 
# ax.plot(df.index, df["Adj Close"],linewidth = 2, alpha = .7, label='Adj Close')   
# ax.legend(loc="upper left")     

ax.plot(dogeTweets.index, dogeTweets["Open"],"bo", label="Musk's Tweets")
ax.legend(loc="upper left") 
ax.set(xlabel="Date",
       title="DOGECOIN on Elon Musk's Tweets")
# Format the x axis
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=10))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%m-%d-%y"))



#ax.xaxis.zoom(0.5)

# Adding Logo
watermark=image.imread("/content/stanford-tree-logo1.png")
plt.figimage(watermark, 350, 40, zorder=1, alpha=0.3)
# Adding Logo
logo=image.imread("/content/rodincode-circle.png")
addLogo = OffsetImage(logo, zoom=0.4)
addLogo.set_zorder(100)
addLogo.set_offset((925,10)) # pass the position in a tuple
ax.add_artist(addLogo)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.image as image
from matplotlib.offsetbox import  OffsetImage
plt.style.use("fivethirtyeight")

fig, ax = plt.subplots(figsize=(15,7))

ax.plot(bit_df.index, bit_df["Open"],linewidth = 2, alpha = .7, label='Open')
ax.legend(loc="upper left") 
ax.plot(bit_df.index, bit_df["High"],linewidth = 2, alpha = .7, label='High') 
ax.legend(loc="upper left")       
ax.plot(bit_df.index, bit_df["Low"],linewidth = 2, alpha = .7, label='Low')
ax.legend(loc="upper left")        
# ax.plot(df.index, df["Close"],linewidth = 2, alpha = .7, label='Close')
# ax.legend(loc="upper left") 
# ax.plot(df.index, df["Adj Close"],linewidth = 2, alpha = .7, label='Adj Close')   
# ax.legend(loc="upper left")     

ax.plot(bitTweets.index, bitTweets["Open"],"bo", label="Dorsey's Tweets")
ax.legend(loc="upper left") 
ax.set(xlabel="Date",
       title="BITCOIN on Jack Dorsey's Tweets")
# Format the x axis
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=10))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%m-%d-%y"))


ax.xaxis.zoom(0.5)

# Adding Logo
watermark=image.imread("/content/stanford-tree-logo1.png")
plt.figimage(watermark, 350, 40, zorder=1, alpha=0.3)
# Adding Logo
logo=image.imread("/content/rodincode-circle.png")
addLogo = OffsetImage(logo, zoom=0.4)
addLogo.set_zorder(100)
addLogo.set_offset((950,10)) # pass the position in a tuple
ax.add_artist(addLogo)

plt.show()
